# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
plt.style.use("ggplot")
from matplotlib.pyplot import figure 

plt.rcParams['figure.figsize'] = (12,8)


df=pd.read_csv(r'C:\Users\jomin\Downloads\archive\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
#looking for missing data 

df.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
 

df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0).astype(int)
df['gross'] = pd.to_numeric(df['gross'], errors='coerce').fillna(0).astype(int)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
year_new = []

for i in df['released']:
    i = str(i)
    year_new.append(i.split('(',1)[0])

# %%
len(year_new) == len(df.released)
# Out:
# True

# %%
df['year_new'] = year_new

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df['released_year']= df['year_new'].str[-5:]

# %%
df.released_year
# Out:
# 0       1980
# 1       1980
# 2       1980
# 3       1980
# 4       1980
#         ...
# 7663    2020
# 7664    2020
# 7665    2020
# 7666    2020
# 7667    2020
# Name: released_year, Length: 7668, dtype: object

# %%
 df.sort_values(by=['gross'],ascending = False,inplace = False )
# Out:
#                                             name     rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# 7480                               The Lion King         PG  Animation  2019
# 6653                              Jurassic World      PG-13     Action  2015
# 6043                                The Avengers      PG-13     Action  2012
# ...                                          ...        ...        ...   ...
# 5033                            Loving Annabelle  Not Rated      Drama  2006
# 7667                                   Tee em el        NaN     Horror  2020
# 3045                                     Titanic      PG-13      Drama  1997
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 5445                                      Avatar      PG-13     Action  2009
#
# ...

# %%
#visualization

plt.scatter(x=df.budget,y=df.gross)
plt.title('budget vs gross')
plt.xlabel('budget')
plt.ylabel('gross')
plt.show()

# %%
sns.regplot(x=df.budget,y=df.gross,data=df,scatter_kws = {"color":"red",},line_kws = {"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
sns.heatmap(data=df.corr(),annot= True)
plt.title('correlation matrix')
plt.xlabel('features ')
plt.ylabel('features')
# Out:
# C:\Users\jomin\AppData\Local\Temp\ipykernel_25168\1103490249.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot= True)
# Text(120.72222222222221, 0.5, 'features')

# %%
new_df = df

# %%
for i in new_df:
    if(new_df[i].dtype == 'object'):
        new_df[i] = new_df[i].astype('category')
        new_df[i] = new_df[i].cat.codes
        
new_df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
sns.heatmap(data=new_df.corr(),annot= False)
plt.title('correlation matrix')
plt.xlabel('features ')
plt.ylabel('features')
# Out:
# Text(120.58159722222221, 0.5, 'features')

# %%
corellation_matrix = new_df.corr()
corr_pair = corellation_matrix.unstack()

# %%
corr_pair
# Out:
# name           name             1.000000
#                rating          -0.008069
#                genre            0.016355
#                year             0.011453
#                released        -0.011311
#                                   ...
# released_year  gross            0.249272
#                company         -0.016109
#                runtime          0.120636
#                year_new        -0.003913
#                released_year    1.000000
# Length: 289, dtype: float64

# %%
sorted_pair = corr_pair.sort_values()

# %%
sorted_pair
# Out:
# budget         genre           -0.334021
# genre          budget          -0.334021
#                gross           -0.229534
# gross          genre           -0.229534
# genre          votes           -0.145307
#                                   ...
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# year_new       year_new         1.000000
# released_year  released_year    1.000000
# Length: 289, dtype: float64

# %%
high_corr = sorted_pair[(sorted_pair) >.5]

# %%
high_corr
# Out:
# votes          gross            0.573889
# gross          votes            0.573889
# budget         gross            0.687124
# gross          budget           0.687124
# released_year  year             0.997295
# year           released_year    0.997295
# year_new       released         0.998400
# released       year_new         0.998400
# name           name             1.000000
# writer         writer           1.000000
# runtime        runtime          1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# released       released         1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# ...

# %%
#gross and the budj
